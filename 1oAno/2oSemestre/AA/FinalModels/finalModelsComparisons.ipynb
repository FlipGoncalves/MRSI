# %%
import matplotlib.pyplot as plt

legend = ["Day Grouping", "Station Grouping", "Trips Grouping"]

# %%
MSEday = [1.3802982568740845, 1.3934881806373596, 1.3683298230171204, 1.3703790664672852, 1.3810015797615052, 1.3837175965309143]
MSEstation = [1.4124974727630615, 1.4019839406013488, 1.4195882439613343, 1.3961206436157227, 1.4007801771163941, 1.3863590478897094, 1.4167989015579223, 1.4111652970314026]
MSEtrip = [1.3705399096012116, 1.4019769132137299, 1.3526817679405212, 1.3668462038040161, 1.3761034727096557]

plt.plot(list(range(1,7)), MSEday, marker="o")
plt.plot(list(range(1,9)), MSEstation, marker="o")
plt.plot(list(range(1,6)), MSEtrip, marker="o")
plt.legend(["Day Grouping", "Station Grouping", "Trip Grouping"])
plt.xlabel("Models")
plt.ylabel("MAE")
# Out:
# Text(0, 0.5, 'MAE')

# %%
plt.plot(legend, [1.2, 1.2, 1.2], marker="o")
plt.plot(legend, [1.4, 1.5, 1.4], marker="o")
plt.legend(["Regression", "LSTM"])
# plt.title("Mean Absolute Error - Regression Comparison")
plt.xlabel("Models")
plt.ylabel("MAE")
# Out:
# Text(0, 0.5, 'MAE')

# %%
plt.plot(legend, [1.0, 1.0, 1.0], marker="o")
plt.plot(legend, [1.4, 1.4, 1.4], marker="o")
# plt.title("Mean Absolute Error - Comparison")
plt.legend(["Regression", "LSTM"])
plt.xlabel("Models")
plt.ylabel("MAE")
# Out:
# Text(0, 0.5, 'MAE')
